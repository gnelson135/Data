# %%
import pandas as pd 

df = pd.read_csv("Destinations2.csv")

data.shape
# Out:
# (15, 5)

# %%
print(df.iloc[3:9])
# Out:
#   Destinations  Feedback_score  Average_hotel_star _rating  \
# 3       Sicily               5                         4.0
# 4     Thailand               8                         5.0
# 5          USA               6                         4.6
# 6    Lithuania               7                         4.1
# 7       Mexico              10                         5.0
# 8     Portugal               9                         4.0
#
#    Number_of_all-inclusive_hotels Most_visited_city
# 3                              44           Palermo
# 4                              67           Bangkok
# 5                             145          New York
# 6                              50           Vilnius
# 7                             200             Talum
# 8                             193             Porto

# %%
print(df.loc[[3,4,5,6,7,8]])
# Out:
#   Destinations  Feedback_score  Average_hotel_star _rating  \
# 3       Sicily               5                         4.0
# 4     Thailand               8                         5.0
# 5          USA               6                         4.6
# 6    Lithuania               7                         4.1
# 7       Mexico              10                         5.0
# 8     Portugal               9                         4.0
#
#    Number_of_all-inclusive_hotels Most_visited_city
# 3                              44           Palermo
# 4                              67           Bangkok
# 5                             145          New York
# 6                              50           Vilnius
# 7                             200             Talum
# 8                             193             Porto

# %%
#3 - Mean number of all-inclusive hotels across all destinations

data["Number_of_all-inclusive_hotels"].mean()
# Out:
# 103.66666666666667

# %%
#4 - Lowest Scroing Destination

print(df["Feedback_score"].min())



#5 Highest Scoring Destination
print(df["Feedback_score"].max())
# Out:
# 5
# 10

# %%
#6 -Find all the destinations where there are more than 9 all-inclusive hotels.

data[(df.Feedback_score) > 9]
# Out:
#    Destinations  Feedback_score  Average_hotel_star _rating  \
# 7        Mexico              10                         5.0
# 9         Japan              10                         4.7
# 14         Cuba              10                         3.9
#
#     Number_of_all-inclusive_hotels Most_visited_city
# 7                              200             Talum
# 9                              132             Tokyo
# 14                              82            Havana

# %%
#7 -Filter the data by destination and score above 8. 

filt = df["Feedback_score"] > 8
#print(filt)

above8 = df[filt]

above8.head()
# Out:
#    Destinations  Feedback_score  Average_hotel_star _rating  \
# 0         Aruba               9                         4.5
# 7        Mexico              10                         5.0
# 8      Portugal               9                         4.0
# 9         Japan              10                         4.7
# 12  South Korea               9                         4.9
#
#     Number_of_all-inclusive_hotels Most_visited_city
# 0                               83        Palm beach
# 7                              200             Talum
# 8                              193             Porto
# 9                              132             Tokyo
# 12                              89             Soeul

# %%
#8 -Filter the data by destination and score below 2 ( I need to know if these destinations should be removed or there is a problem)     

filt2= df["Feedback_score"] < 2

below2 = df[filt2]
#print(filt2)

below2.head()
# Out:
# Empty DataFrame
# Columns: [Destinations, Feedback_score, Average_hotel_star _rating, Number_of_all-inclusive_hotels, Most_visited_city]
# Index: []

# %%
# 9 Is there a correlation between number of all-inclusive hotels and score?

df.plot.scatter(x="Feedback_score", y="Number_of_all-inclusive_hotels")

# %%
#10 -Create a data visualisation diagram to show destination and highest scores?

df.plot.bar(x="Destinations", y="Feedback_score") 

#order = df.sort_values("Feedback_score", ascending = True))"""

#data.set
